# %% [markdown]
# # Settings

# %%
NB_FEATURES = 14
NB_VALUES = 3
NB_TESTS_PER_SETTINGS = 10
MAX_RULES = 10000
STEP_SIZE = 100
RULES_CONDITIONS = 1.0
BRUTEFORCE = False

DEBUG = False

MAX_LOOP = 1000000

SEED = 42

if DEBUG:
    NB_FEATURES = 5
    NB_VALUES = 3 
    NB_TESTS_PER_SETTINGS = 10
    MAX_RULES = 100
    STEP_SIZE = 10

# %%
from pylfit.postprocessing import compute_counterfactuals, bruteforce_counterfactuals
from pylfit.objects import LegacyAtom, Rule
from pylfit.models import DMVLP
from pylfit.datasets import DiscreteStateTransitionsDataset

import random
import time
import pandas
import seaborn as sns
from matplotlib import colors as mcolors

import matplotlib.pyplot as plt

from itertools import chain, combinations

random.seed(SEED)

# %%
def random_rule(head, features, max_body_size):
    body = {}
    nb_conditions = random.randint(1,max_body_size)
    while len(body) < nb_conditions:
        var_id = random.randint(0, len(features)-1)
        val = random.choice(features[var_id][1])
        atom = LegacyAtom(variable=features[var_id][0], domain=set(features[var_id][1]), value=val, state_position=var_id)
        valid = True
        for var in body:
            if body[var].state_position == atom.state_position:
                valid = False
                break
        if valid:
            body[atom.variable] = atom
        
    r = Rule(head,body)

    return r

def random_rule_that_matches(feature_state, head, features, max_body_size):
    body = {}
    nb_conditions = random.randint(1,max_body_size)
    while len(body) < nb_conditions:
        var_id = random.randint(0, len(feature_state)-1)
        atom = LegacyAtom(variable=features[var_id][0], domain=set(features[var_id][1]), value=feature_state[var_id], state_position=var_id)
        valid = True
        for var in body:
            if body[var].state_position == atom.state_position:
                valid = False
                break
        if valid:
            body[atom.variable] = atom
        
    r = Rule(head,body)

    return r


def powerset(iterable):
    "powerset([1,2,3]) --> () (1,) (2,) (3,) (1,2) (1,3) (2,3) (1,2,3)"
    s = list(iterable)
    return chain.from_iterable(combinations(s, r) for r in range(len(s)+1))

# %% [markdown]
# # Compute counterfactual with proposal

# %%
# Generate a DMVLP of X rules
features = [("x"+str(i), ["val_"+str(val) for val in range(0,NB_VALUES)]) for i in range(NB_FEATURES)]
targets = [("y", ["val_"+str(val) for val in range(0,NB_VALUES)])]
rules = []

model = DMVLP(features=features, targets=targets)
model.compile()
model.summary()

features_states = model.feature_states()
print("Features states:", len(features_states))

target = targets[0][0]
target_domain = targets[0][1]
print("target:", target, target_domain)
# Out:
# DMVLP summary:
#  Algorithm: gula
#  Features:
#   x0: ['val_0', 'val_1', 'val_2']
#   x1: ['val_0', 'val_1', 'val_2']
#   x2: ['val_0', 'val_1', 'val_2']
#   x3: ['val_0', 'val_1', 'val_2']
#   x4: ['val_0', 'val_1', 'val_2']
#   x5: ['val_0', 'val_1', 'val_2']
#   x6: ['val_0', 'val_1', 'val_2']
#   x7: ['val_0', 'val_1', 'val_2']
#   x8: ['val_0', 'val_1', 'val_2']
#   x9: ['val_0', 'val_1', 'val_2']
#   x10: ['val_0', 'val_1', 'val_2']
#   x11: ['val_0', 'val_1', 'val_2']
#   x12: ['val_0', 'val_1', 'val_2']
#   x13: ['val_0', 'val_1', 'val_2']
#  Targets:
#   y: ['val_0', 'val_1', 'val_2']
#  Rules: []
# Features states: 4782969
# target: y ['val_0', 'val_1', 'val_2']

# %%
data = []
nb_rules = 10
nb_power = 1
while nb_rules < MAX_RULES:
    nb_rules = 10**nb_power
    nb_power += 1
    print("Rules:",str(nb_rules)+"/"+str(MAX_RULES))
    for test in range(NB_TESTS_PER_SETTINGS):
        print("\rTest:", str(test+1)+"/"+str(NB_TESTS_PER_SETTINGS),end='')
        
        # Generate the counterfactual problem first
        s = random.choice(features_states)
        val_out = random.choice(target_domain)
        val_in = val_out
        while(val_in == val_out):
            val_in = random.choice(target_domain)

        #print("s:", s)
        #print("Val_out:", val_out)
        #print("Val_in:", val_in)
        
        # Create rules for each target value so that the problem is valid
        rules = []
        for val in target_domain:
            val_rules = []
            head = LegacyAtom(variable=target, domain=set(target_domain), value=val, state_position=0)

            loops = 0
            while(len(val_rules) < nb_rules and loops < MAX_LOOP):
                loops += 1
                
                if val == val_out: # s must be matched
                    rule = random_rule_that_matches(s, head, features, int(len(features)*RULES_CONDITIONS))
                else:
                    rule = random_rule(head, features, int(len(features)*RULES_CONDITIONS))

                #print(rule)

                if val == val_in: # s should not match
                    if rule.matches(s):
                        #print("OUT: matches",s)
                        continue

                # Rule must be minimal
                valid = True
                if rule in val_rules:
                    #print("OUT: already in rules")
                    valid = False

                #for r in val_rules:
                #    if r.subsumes(rule) or rule.subsumes(r):
                #        valid = False
                #        break

                if not valid:
                    continue
                
                val_rules.append(rule)

            if loops >= MAX_LOOP:
                print("ERROR, MAX_LOOP reached, cannot find rule valid")
                print("Rules found:", len(val_rules))
            
            rules += val_rules

            #print("Created rules for",str(val),len(val_rules))

        # Minimize the dmvlp

        model = DMVLP(features, targets, rules)
        model.compile()
        #model.summary()

        if BRUTEFORCE:
            begin = time.time()
            solutions = bruteforce_counterfactuals(model, s, target, [val_out], [val_in])[val_in]
            run_time = time.time() - begin
            data.append(["Naïve enumeration", len(model.features), nb_rules, s, val_out, val_in, solutions, len(solutions), run_time])

        begin = time.time()
        solutions = compute_counterfactuals(model, s, target, [val_out], [val_in])[val_in]
        run_time = time.time() - begin
        data.append(["CELOS", len(model.features), nb_rules, s, val_out, val_in, solutions, len(solutions), run_time])
        
        #for i in solutions:
        #    print(i)

    print()
    
df = pandas.DataFrame(data, columns=["method", "features", "rules", "feature_state", "val_out", "val_in", "solutions", "nb_solutions", "run_time"])
display(df)
# Out:
# Rules: 10/10000
# Test: 10/10
# Rules: 100/10000
# Test: 10/10
# Rules: 1000/10000
# Test: 10/10
# Rules: 10000/10000
# Test: 10/10
#    method  features  rules                                      feature_state  \
# 0   CELOS        14     10  [val_0, val_1, val_2, val_0, val_2, val_1, val...
# 1   CELOS        14     10  [val_2, val_1, val_1, val_0, val_0, val_0, val...
# 2   CELOS        14     10  [val_2, val_0, val_0, val_2, val_0, val_2, val...
# 3   CELOS        14     10  [val_1, val_0, val_2, val_2, val_2, val_1, val...
# 4   CELOS        14     10  [val_0, val_1, val_0, val_1, val_1, val_1, val...
# 5   CELOS        14     10  [val_2, val_1, val_1, val_2, val_1, val_2, val...
# 6   CELOS        14     10  [val_2, val_2, val_2, val_2, val_1, val_0, val...
# 7   CELOS        14     10  [val_1, val_1, val_1, val_2, val_1, val_1, val...
# 8   CELOS        14     10  [val_2, val_1, val_0, val_1, val_2, val_1, val...
# 9   CELOS        14     10  [val_0, val_0, val_1, val_1, val_2, val_0, val...
# 10  CELOS        14    100  [val_2, val_2, val_1, val_1, val_0, val_1, val...
# 11  CELOS        14    100  [val_2, val_0, val_2, val_2, val_0, val_0, val...
# 12  CELOS        14    100  [val_1, val_0, val_0, val_0, val_2, val_1, val...
# 13  CELOS        14    100  [val_1, val_2, val_0, val_2, val_1, val_2, val...
# 14  CELOS        14    100  [val_0, val_0, val_1, val_0, val_1, val_2, val...
# 15  CELOS        14    100  [val_0, val_0, val_2, val_1, val_1, val_0, val...
# 16  CELOS        14    100  [val_2, val_1, val_2, val_1, val_2, val_0, val...
# 17  CELOS        14    100  [val_0, val_0, val_0, val_2, val_2, val_1, val...
# 18  CELOS        14    100  [val_0, val_1, val_0, val_1, val_1, val_2, val...
# 19  CELOS        14    100  [val_0, val_1, val_1, val_0, val_2, val_0, val...
# 20  CELOS        14   1000  [val_0, val_1, val_2, val_0, val_1, val_1, val...
# 21  CELOS        14   1000  [val_1, val_1, val_1, val_1, val_2, val_2, val...
# 22  CELOS        14   1000  [val_0, val_1, val_0, val_1, val_1, val_2, val...
# 23  CELOS        14   1000  [val_0, val_2, val_1, val_0, val_0, val_1, val...
# 24  CELOS        14   1000  [val_0, val_2, val_0, val_0, val_2, val_0, val...
# 25  CELOS        14   1000  [val_1, val_1, val_0, val_2, val_1, val_2, val...
# 26  CELOS        14   1000  [val_0, val_0, val_2, val_2, val_0, val_2, val...
# 27  CELOS        14   1000  [val_1, val_1, val_1, val_1, val_1, val_2, val...
# 28  CELOS        14   1000  [val_2, val_0, val_1, val_1, val_1, val_2, val...
# 29  CELOS        14   1000  [val_0, val_2, val_1, val_0, val_2, val_0, val...
# 30  CELOS        14  10000  [val_0, val_2, val_0, val_0, val_0, val_0, val...
# 31  CELOS        14  10000  [val_2, val_1, val_0, val_2, val_2, val_2, val...
# 32  CELOS        14  10000  [val_1, val_0, val_2, val_0, val_0, val_0, val...
# 33  CELOS        14  10000  [val_2, val_0, val_1, val_0, val_0, val_0, val...
# 34  CELOS        14  10000  [val_1, val_2, val_2, val_1, val_0, val_2, val...
# 35  CELOS        14  10000  [val_0, val_2, val_2, val_2, val_2, val_2, val...
# 36  CELOS        14  10000  [val_0, val_0, val_1, val_0, val_1, val_0, val...
# 37  CELOS        14  10000  [val_1, val_1, val_1, val_2, val_2, val_1, val...
# 38  CELOS        14  10000  [val_1, val_1, val_1, val_0, val_2, val_0, val...
# 39  CELOS        14  10000  [val_0, val_0, val_1, val_0, val_2, val_1, val...
#
#    val_out val_in                                          solutions  \
# 0    val_0  val_2  [{x9(val_1), x6(val_2), x5(val_2), x11(val_0),...
# 1    val_2  val_1  [{x13(val_2), x4(val_1), x11(val_2), x5(val_1)...
# 2    val_1  val_0  [{x3(val_1), x11(val_2), x13(val_1), x8(val_0)...
# 3    val_2  val_0  [{x0(val_0), x7(val_2), x6(val_2), x11(val_0)}...
# 4    val_1  val_2  [{x5(val_2), x7(val_1), x1(val_2)}, {x9(val_0)...
# 5    val_2  val_1  [{x8(val_2), x13(val_1), x10(val_1)}, {x13(val...
# 6    val_1  val_2  [{x13(val_1), x8(val_0), x2(val_0)}, {x13(val_...
# 7    val_0  val_1  [{x2(val_2), x11(val_0), x10(val_1)}, {x10(val...
# 8    val_1  val_0  [{x1(val_0), x12(val_2), x2(val_1), x10(val_1)...
# 9    val_2  val_0  [{x11(val_2), x3(val_2), x8(val_0), x0(val_1),...
# 10   val_0  val_1  [{x11(val_2), x5(val_0), x12(val_0), x7(val_1)...
# 11   val_1  val_2  [{x11(val_2), x6(val_0), x0(val_1), x8(val_2),...
# 12   val_0  val_1  [{x6(val_2), x2(val_1), x3(val_2), x1(val_2), ...
# 13   val_2  val_1  [{x6(val_2), x5(val_0), x13(val_2), x7(val_1),...
# 14   val_1  val_2  [{x6(val_0), x0(val_1), x8(val_2), x7(val_1), ...
# 15   val_0  val_1  [{x7(val_0), x2(val_0), x6(val_2), x4(val_0), ...
# 16   val_0  val_1  [{x11(val_1), x4(val_1), x8(val_0), x6(val_0),...
# 17   val_0  val_2  [{x4(val_0), x10(val_0), x0(val_2), x13(val_2)...
# 18   val_0  val_2  [{x11(val_1), x4(val_0), x3(val_2), x12(val_1)...
# 19   val_2  val_0  [{x2(val_0), x1(val_2), x12(val_0), x8(val_2),...
# 20   val_2  val_1  [{x2(val_1), x3(val_2), x6(val_0), x12(val_2),...
# 21   val_2  val_0  [{x2(val_0), x11(val_2), x5(val_1), x4(val_0),...
# 22   val_0  val_1  [{x2(val_1), x5(val_0), x1(val_2), x12(val_0),...
# 23   val_0  val_1  [{x2(val_0), x11(val_2), x3(val_2), x12(val_1)...
# 24   val_1  val_0  [{x11(val_1), x13(val_1), x5(val_1), x4(val_0)...
# 25   val_0  val_1  [{x7(val_0), x11(val_2), x2(val_1), x8(val_0),...
# 26   val_0  val_1  [{x7(val_0), x11(val_2), x2(val_1), x8(val_0),...
# 27   val_0  val_2  [{x11(val_2), x5(val_1), x4(val_0), x12(val_0)...
# 28   val_2  val_0  [{x7(val_0), x11(val_1), x12(val_2), x6(val_0)...
# 29   val_0  val_1  [{x7(val_0), x4(val_1), x2(val_0), x5(val_1), ...
# 30   val_1  val_2  [{x7(val_0), x2(val_2), x4(val_1), x6(val_2), ...
# 31   val_0  val_1  [{x11(val_1), x7(val_0), x6(val_2), x0(val_0),...
# 32   val_1  val_0  [{x4(val_1), x11(val_2), x0(val_0), x2(val_1),...
# 33   val_0  val_2  [{x11(val_1), x2(val_0), x6(val_2), x8(val_0),...
# 34   val_0  val_2  [{x2(val_0), x5(val_1), x12(val_2), x6(val_0),...
# 35   val_1  val_0  [{x11(val_1), x7(val_0), x4(val_1), x2(val_1),...
# 36   val_1  val_2  [{x11(val_1), x2(val_0), x6(val_2), x5(val_1),...
# 37   val_1  val_0  [{x11(val_1), x7(val_0), x4(val_1), x1(val_2),...
# 38   val_2  val_1  [{x4(val_1), x6(val_2), x11(val_2), x3(val_2),...
# 39   val_0  val_2  [{x2(val_2), x6(val_2), x4(val_0), x8(val_0), ...
#
#     nb_solutions     run_time
# 0             32     0.008991
# 1            314     0.226242
# 2            307     0.059672
# 3            206     0.128613
# 4             45     0.086265
# 5             25     0.095914
# 6             48     0.046268
# 7            184     0.031961
# 8             45     0.029189
# 9            341     0.537067
# 10          1072    36.920120
# 11          1144     3.727882
# 12          4040    75.664031
# 13          1742     9.161625
# 14          1563     8.609716
# 15          2743    42.528149
# 16          1714    11.292619
# 17         14052  1020.834182
# 18          4660    38.014798
# 19           298     3.030709
# 20         16384   495.715943
# 21         16384   314.983444
# 22         16384  2052.493561
# 23         16384   427.109644
# 24         16384   373.310817
# 25         16384   171.828605
# 26         16384   470.647062
# 27         16384   193.635273
# 28         16384   416.480128
# 29         16384   326.063038
# 30         16384   488.122839
# 31         16384   706.929168
# 32         16384   959.955423
# 33         16384   529.925736
# 34         16384   517.724128
# 35         16384   571.409067
# 36         16384   480.173441
# 37         16384   495.508882
# 38         16384   569.343606
# 39         16384   728.077620

# %%
df[df["nb_solutions"]>0]

df.to_csv("results_random_rules.csv")

# %% [markdown]
# # Visualize performance

# %%
BRUTE_FORCE_COLOR = mcolors.to_rgba("#C6110B") #"lightcoral"
GULA_COLOR = mcolors.to_rgba("#0B7FF3") #"skyblue"
WHIS_VALUE = 10000000

# %%
#df_brute_force = df_semantics[df_semantics["method"] == "brute_force"]
ax = sns.boxplot(x="rules", y="nb_solutions", data=df,
                #whiskerprops = dict(color=BRUTE_FORCE_COLOR, linewidth=2.0, alpha= 0.8),
                #capprops = dict(color=BRUTE_FORCE_COLOR, linewidth=2.0, alpha= 0.8),
                whis=WHIS_VALUE,
                palette="Blues",
                log_scale=False)
# Out:
# C:\Users\Tony\AppData\Local\Temp\ipykernel_27452\2662625745.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(x="rules", y="nb_solutions", data=df,

# %%
#df_brute_force = df_semantics[df_semantics["method"] == "brute_force"]
ax = sns.boxplot(x="rules", y="run_time", hue="method", data=df,
                #whiskerprops = dict(color=BRUTE_FORCE_COLOR, linewidth=2.0, alpha= 0.8),
                #capprops = dict(color=BRUTE_FORCE_COLOR, linewidth=2.0, alpha= 0.8),
                whis=WHIS_VALUE,
                palette="Blues",
                log_scale=False)

#plt.savefig("random_rules_run_times.pdf", bbox_inches='tight')

# %%
df_tmp = df.copy()
df_tmp["run_time"] += 0.001
ax = sns.boxplot(x="rules", y="run_time", hue="method", data=df_tmp,
                #whiskerprops = dict(color=BRUTE_FORCE_COLOR, linewidth=2.0, alpha= 0.8),
                #capprops = dict(color=BRUTE_FORCE_COLOR, linewidth=2.0, alpha= 0.8),
                whis=WHIS_VALUE,
                palette="Blues",
                log_scale=True)

plt.savefig("random_run_times.pdf", bbox_inches='tight')

# %% [markdown]
# # DEBUG
